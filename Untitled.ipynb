# %%
import accelforge as af
from scheduling.scheduler import *
from af_wrapper import *
import numpy as np

# %%
arch = "arch/tpu-v4i/tpu_v4i.yaml"
workload = "workload/milestone-2/full.yaml"

# %%
spec = af.Spec.from_yaml(
    arch,
    workload
)

# %%
spec.arch
# Out:
# Arch(nodes=ArchNodes([Container(spatial=[], name='system'), Memory(name='DRAM', spatial=[], component_class='LPDDR4', component_model=None, component_modeling_log=[], actions=[TensorHolderAction(name='read', energy=None, energy_scale=1, latency=None, latency_scale=1, extra_attributes_for_component_model=EvalExtras(), bits_per_action=16), TensorHolderAction(name='write', energy=None, energy_scale=1, latency=None, latency_scale=1, extra_attributes_for_component_model=EvalExtras(), bits_per_action=16)], enabled=True, area=None, total_area=None, area_scale=1, leak_power=None, total_leak_power=None, leak_power_scale=1, energy_scale=1, total_latency='sum(*action2latency.values())', latency_scale=1, n_parallel_instances=1, extra_attributes_for_component_model=_ExtraAttrs(width=64), tensors=Tensors(keep='<Defaults to Nothing>', may_keep='<Nothing if keep is defined, else All>', back='Nothing', tile_shape=[], no_refetch_from_above='~All', no_resend_to_below='~All', tensor_order_options=[], fo
# ...

# %%
filename = 'tpu'

# %%
with open("images/" + filename + ".svg", "w") as f:
    f.write(spec.arch.render())

# %%
arch = "arch/fusemax/full.yaml"
workload = "workload/milestone-2/full.yaml"
spec = af.Spec.from_yaml(
    arch,
    workload
)
spec.arch
# Out:
# Arch(nodes=ArchNodes([Container(spatial=[], name='system'), Memory(name='DRAM', spatial=[], component_class='LPDDR4', component_model=None, component_modeling_log=[], actions=[TensorHolderAction(name='read', energy=None, energy_scale=1, latency=None, latency_scale=1, extra_attributes_for_component_model=EvalExtras(), bits_per_action=16), TensorHolderAction(name='write', energy=None, energy_scale=1, latency=None, latency_scale=1, extra_attributes_for_component_model=EvalExtras(), bits_per_action=16)], enabled=True, area=None, total_area=None, area_scale=1, leak_power=None, total_leak_power=None, leak_power_scale=1, energy_scale=1, total_latency='(read_actions + write_actions) / 2.147e11', latency_scale=1, n_parallel_instances=1, extra_attributes_for_component_model=_ExtraAttrs(width=64), tensors=Tensors(keep='<Defaults to Nothing>', may_keep='<Nothing if keep is defined, else All>', back='Nothing', tile_shape=[], no_refetch_from_above='~All', no_resend_to_below='~All', tensor_order_op
# ...

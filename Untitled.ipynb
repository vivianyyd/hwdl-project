# %%
import accelforge as af

def trunc(s):
    return s.rsplit("/", 1)[-1].rsplit(".yaml", 1)[0]


def map(arch, workload):
    spec = af.Spec.from_yaml(
        arch,
        workload
    )
    spec.mapper.metrics = af.Metrics.LATENCY | af.Metrics.ENERGY 
    mapping = spec.map_workload_to_arch()

    filename = trunc(arch) + "-" + trunc(workload)
    with open("images/" + filename + ".svg", "w") as f:
        f.write(mapping.render())

    actions = mapping.actions(per_einsum=True, per_component=True)
    latency = mapping.latency(per_einsum=True)
    
    total_reads = 0
    total_writes = 0
    for (einsum, lat) in latency.items():
        component = "MainMemory"
        reads = actions[(einsum, component, "read")]
        writes = actions[(einsum, component, "write")]
        total_reads += reads
        total_writes += writes

    rw = total_reads + total_writes
    latency = mapping.latency()

    mem_actions = {}
    for (op, mem, action), value in actions.items():
        if action != "compute" and mem == "MainMemory":   # ignore compute entries
            key = (op, mem)
            mem_actions[key] = mem_actions.get(key, 0.0) + value
    
    return {
        'mapping': mapping,
        'total reads': total_reads,
        'total write': total_writes,
        'total r+w': rw,
        'latency': latency,
        '(r+w)/latency': rw / latency,
        'bw util': (rw/latency) / 6.4e9, # todo ugly i am hardcoded
        'mem summary': mem_actions
    }

# %%
# %%capture captured_output 
# view stdout by running captured_output.show()

full_boundmemlat = map(
    "eyeriss-submods/full-boundmainmemlat.yaml",
    "matmulvecmul/full-workload.yaml"
)

full_unboundmemlat = map(
    "eyeriss-submods/full-unboundmainmemlat.yaml",
    "matmulvecmul/full-workload.yaml"
)
# Out:
# Generating pmapping templates for compute SlowMAC Einsum Matvec: 16it [00:00, 79.78it/s]it/s]
# Generating pmapping templates for compute SlowMAC Einsum Matmulmatvec: 16it [00:00, 80.05it/s]
# Generating pmapping templates for compute SlowMAC Einsum Matmul: 16it [00:00, 78.19it/s]
# Generating pmapping templates for compute FastMAC Einsum Matmulmatvec: 16it [00:00, 81.85it/s]
# Generating pmapping templates for compute FastMAC Einsum Matmul: 16it [00:00, 77.18it/s]
# Generating pmapping templates for compute FastMAC Einsum Matvec: 16it [00:00, 44.89it/s]
# Generating pmapping templates for compute SlowMAC Einsum Matvec: 16it [00:00, 95.88it/s]3it/s]
# Generating pmapping templates for compute SlowMAC Einsum Matmulmatvec: 16it [00:00, 93.36it/s]
# Generating pmapping templates for compute SlowMAC Einsum Matmul: 16it [00:00, 90.20it/s]
# Generating pmapping templates for compute FastMAC Einsum Matmulmatvec: 16it [00:00, 88.58it/s]
# Generating pmapping templates for compute FastMAC Einsum Matvec: 16it [00:00, 88.26it/s]
# Generating pmapping templates for compute FastMAC Einsum Matmul: 16it [00:00, 85.58it/s]

# %%
full_boundmemlat
# Out:
# {'mapping': <accelforge.mapper.FFM.mappings.Mappings at 0x7f40dbeed430>,
#  'total reads': 526336.0,
#  'total write': 133120.0,
#  'total r+w': 659456.0,
#  'latency': np.float32(0.00020544),
#  '(r+w)/latency': np.float32(3.209969e+09),
#  'bw util': np.float32(0.50155765),
#  'mem summary': {('Matmul', 'MainMemory'): 393216.0,
#   ('Matvec', 'MainMemory'): 133120.0,
#   ('Matmulmatvec', 'MainMemory'): 133120.0}}

# %%
full_unboundmemlat
# Out:
# {'mapping': <accelforge.mapper.FFM.mappings.Mappings at 0x7f4100657920>,
#  'total reads': 526336.0,
#  'total write': 133120.0,
#  'total r+w': 659456.0,
#  'latency': np.float32(0.0001664),
#  '(r+w)/latency': np.float32(3.9630769e+09),
#  'bw util': np.float32(0.61923075),
#  'mem summary': {('Matmul', 'MainMemory'): 393216.0,
#   ('Matvec', 'MainMemory'): 133120.0,
#   ('Matmulmatvec', 'MainMemory'): 133120.0}}

# %%
full_mapping = full_boundmemlat

# %%
full_mapping['mapping'].actions()
# Out:
# {('FastWeightScratchpad', 'read'): 17039360.0,
#  ('FastWeightScratchpad', 'write'): 4227072.0,
#  ('FastGlobalBuffer', 'read'): 16960.0,
#  ('FastGlobalBuffer', 'write'): 10336.0,
#  ('MainMemory', 'read'): 526336.0,
#  ('MainMemory', 'write'): 133120.0,
#  ('FastInputScratchpad', 'read'): 17039360.0,
#  ('FastInputScratchpad', 'write'): 393216.0,
#  ('FastOutputScratchpad', 'read'): 20201472.0,
#  ('FastOutputScratchpad', 'write'): 20201472.0,
#  ('FastMAC', 'compute'): 2129920.0}

# %%
full_mapping['mapping'].latency(per_component=True, per_einsum=True)
# Out:
# {('Matmul', 'FastMAC'): 0.00016383999900426716,
#  ('Matmul', 'FastWeightScratchpad'): 4.928441740048584e-06,
#  ('Matmul', 'FastGlobalBuffer'): 4.160000116826268e-06,
#  ('Matmul', 'MainMemory'): 6.143999780761078e-05,
#  ('Matmul', 'FastInputScratchpad'): 1.2288031939533539e-05,
#  ('Matmul', 'FastOutputScratchpad'): 2.8957843824173324e-05,
#  ('Matvec', 'FastMAC'): 1.0239999937766697e-05,
#  ('Matvec', 'FastWeightScratchpad'): 2.7722484219339094e-07,
#  ('Matvec', 'FastGlobalBuffer'): 5.249999901479896e-08,
#  ('Matvec', 'MainMemory'): 2.080000012938399e-05,
#  ('Matvec', 'FastOutputScratchpad'): 1.6193530427699443e-06,
#  ('Matvec', 'FastInputScratchpad'): 1.524097001492919e-06,
#  ('Matmulmatvec', 'FastMAC'): 1.0239999937766697e-05,
#  ('Matmulmatvec', 'FastWeightScratchpad'): 2.7722484219339094e-07,
#  ('Matmulmatvec', 'FastGlobalBuffer'): 5.249999901479896e-08,
#  ('Matmulmatvec', 'MainMemory'): 2.080000012938399e-05,
#  ('Matmulmatvec', 'FastInputScratchpad'): 1.524097001492919e-06,
#  ('Matmulmatvec', 'FastOutputScratchpad'): 1.6193530427699443e-06}

# %%
# %%capture grid_output 

grid = {}
for sub_arch in ['fast', 'slow']:
    for einsum in ['matmul', 'matvec', 'matmulmatvec']:
        grid[(sub_arch, einsum)] = map(
            "eyeriss-submods/"+sub_arch+".yaml",
            "matmulvecmul/"+einsum+".yaml"
        )

# %%
grid
# Out:
# {('fast',
#   'matmul'): {'mapping': <accelforge.mapper.FFM.mappings.Mappings at 0x7f40f7557950>, 'total reads': 262144.0, 'total write': 131072.0, 'total r+w': 393216.0, 'latency': np.float32(0.00016384), '(r+w)/latency': np.float32(2.4e+09), 'bw util': np.float32(0.61923075), 'mem summary': {('Matmul',
#     'MainMemory'): 393216.0}},
#  ('fast',
#   'matvec'): {'mapping': <accelforge.mapper.FFM.mappings.Mappings at 0x7f40f73ff740>, 'total reads': 132096.0, 'total write': 1024.0, 'total r+w': 133120.0, 'latency': np.float32(1.28e-06), '(r+w)/latency': np.float32(1.04000004e+11), 'bw util': np.float32(0.61923075), 'mem summary': {('Matvec',
#     'MainMemory'): 133120.0}},
#  ('fast',
#   'matmulmatvec'): {'mapping': <accelforge.mapper.FFM.mappings.Mappings at 0x7f40db91fb60>, 'total reads': 132096.0, 'total write': 1024.0, 'total r+w': 133120.0, 'latency': np.float32(1.28e-06), '(r+w)/latency': np.float32(1.04000004e+11), 'bw util': np.float32(0.61923075), 'mem summary': {('Matmulmatvec',
#     'MainMemory'): 133120.0}},
#  ('slow',
#   'matmul'): {'mapping': <accelforge.mapper.FFM.mappings.Mappings at 0x7f40f7c4ff50>, 'total reads': 262144.0, 'total write': 131072.0, 'total r+w': 393216.0, 'latency': np.float32(0.0016384), '(r+w)/latency': np.float32(2.4e+08), 'bw util': np.float32(0.61923075), 'mem summary': {('Matmul',
#     'MainMemory'): 393216.0}},
#  ('slow',
#   'matvec'): {'mapping': <accelforge.mapper.FFM.mappings.Mappings at 0x7f40fe83e090>, 'total reads': 132096.0, 'total write': 1024.0, 'total r+w': 133120.0, 'latency': np.float32(1.28e-05), '(r+w)/latency': np.float32(1.04e+10), 'bw util': np.float32(0.61923075), 'mem summary': {('Matvec',
#     'MainMemory'): 133120.0}},
#  ('slow',
#   'matmulmatvec'): {'mapping': <accelforge.mapper.FFM.mappings.Mappings at 0x7f4100654830>, 'total reads': 132096.0, 'total write': 1024.0, 'total r+w': 133120.0, 'latency': np.float32(1.28e-05), '(r+w)/latency': np.float32(1.04e+10), 'bw util': np.float32(0.61923075), 'mem summary': {('Matmulmatvec',
#     'MainMemory'): 133120.0}}}

# %%
for k, v in grid.items():
    print(k, v['latency'])

# before we put a latency on dram:
# ('fast', 'matmul') 0.00016384
# ('fast', 'matvec') 1.28e-06
# ('fast', 'matmulmatvec') 1.28e-06
# ('slow', 'matmul') 0.0016384
# ('slow', 'matvec') 1.28e-05
# ('slow', 'matmulmatvec') 1.28e-05
# Out:
# ('fast', 'matmul') 0.00016384
# ('fast', 'matvec') 1.28e-06
# ('fast', 'matmulmatvec') 1.28e-06
# ('slow', 'matmul') 0.0016384
# ('slow', 'matvec') 1.28e-05
# ('slow', 'matmulmatvec') 1.28e-05

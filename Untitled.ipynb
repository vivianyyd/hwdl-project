# %%
import accelforge as af

spec = af.Spec.from_yaml(
    "arch-buf.yaml",
    "gpt.yaml",
    jinja_parse_data={
    }
)

# print(spec.arch)
# print(spec.workload)
print(spec.mapper.metrics)
spec.mapper.metrics = af.Metrics.LATENCY | af.Metrics.ENERGY 

result = spec.map_workload_to_arch()
with open("image.svg", "w") as f:
    f.write(result.render())

print(result.resource_usage())
# Out:
# Metrics.ENERGY
# Getting energy, latency, and leak power for components running QK: 100%|██████████| 4/4 [00:01<00:00,  2.01it/s]
# Generating pmapping templates for compute FastMAC Einsum V: 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/joblib/externals/loky/process_executor.py", line 490, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/joblib/parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/build/accelforge/util/parallel.py", line 183, in f
#     return i, job[0](*job[1], **job[2])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/build/accelforge/mapper/FFM/_make_pmappings/make_pmappings.py", line 149, in make_jobs_for_einsum
#     for j in make_pmapping_templates(job, print_progress):
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/build/accelforge/mapper/FFM/_make_pmappings/make_pmapping_templates/make_pmapping_templates.py", line 428, in make_pmapping_templates
#     for i, (mapping, constraints, symbol_table) in enumerate(mappings_constraints):
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#   File "/home/build/accelforge/mapper/FFM/_make_pmappings/make_pmapping_templates/make_pmapping_templates.py", line 352, in iterate_mappings_constraints
#     for mapping, symbol_table, compute, n_orders in iterate_mappings_no_constraints(
#   File "/home/build/accelforge/mapper/FFM/_make_pmappings/make_pmapping_templates/make_pmapping_templates.py", line 316, in iterate_mappings_no_constraints
#     insert_spatial_loops(
#   File "/home/build/accelforge/mapper/FFM/_make_pmappings/make_pmapping_templates/make_loops.py", line 334, in insert_spatial_loops
#     rank_variables &= tensor2fully_relevant_rank_vars[t]
#                       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^
# KeyError: 'K'
# """
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 15
#      12 print(spec.mapper.metrics)
#      13 spec.mapper.metrics = af.Metrics.LATENCY | af.Metrics.ENERGY
# ---> 15 result = spec.map_workload_to_arch()
#      16 with open("image.svg", "w") as f:
#      17     f.write(result.render())
#
# File /home/build/accelforge/frontend/spec.py:396, in Spec.map_workload_to_arch(self, einsum_names, one_pbar_only, print_progress, print_number_of_pmappings, _pmapping_row_filter_function)
#     360 """
#     361 Maps the workload to the architecture using the AccelForge Fast and Fusiest
#     362 Mapper (FFM).
#    (...)    392     The mappings of the workload to the architecture.
#     393 """
#     394 from accelforge.mapper.FFM.main import map_workload_to_arch
# --> 396 return map_workload_to_arch(
#     397     self,
#     398     einsum_names=einsum_names,
#     399     one_pbar_only=one_pbar_only,
#     400     print_progress=print_progress,
#     401     print_number_of_pmappings=print_number_of_pmappings,
#     402     _pmapping_row_filter_function=_pmapping_row_filter_function,
#     403 )
#
# File /home/build/accelforge/mapper/FFM/main.py:71, in map_workload_to_arch(spec, einsum_names, can_combine_multiple_runs, cache_dir, one_pbar_only, print_progress, print_number_of_pmappings, _pmapping_row_filter_function)
#      68     print_progress = False
#      69     print_number_of_pmappings = False
# ---> 71 pmappings = make_pmappings(
#      72     spec,
#      73     einsum_names=einsum_names,
#      74     print_progress=print_progress,
#      75     can_combine_multiple_runs=can_combine_multiple_runs,
#      76     cache_dir=cache_dir,
#      77     print_number_of_pmappings=print_number_of_pmappings,
#      78     one_pbar_only=one_pbar_only,
#      79 )
#      81 mappings = join_pmappings(
#      82     pmappings,
#      83     require_all_einsums=False,
#    (...)     86     metrics=spec.mapper.metrics,
#      87 )
#      89 def eval_mapping(i, spec, mappings):
#
# File /home/build/accelforge/mapper/FFM/main.py:187, in make_pmappings(spec, einsum_names, can_combine_multiple_runs, cache_dir, print_progress, print_number_of_pmappings, one_pbar_only)
#     184 assert len(kwargs) == len(inspect.signature(_make_pmappings).parameters)
#     186 if cache_dir is None:
# --> 187     result = _make_pmappings(**kwargs)
#     188 else:
#     190     @joblib.Memory(location=os.path.join(cache_dir), compress=True).cache
#     191     def _make_pmappings_cached(**kwargs) -> MultiEinsumPmappings:
#
# File /home/build/accelforge/mapper/FFM/main.py:253, in _make_pmappings(spec, einsum_names, can_combine_multiple_runs, print_progress, one_pbar_only)
#     250 if einsum_names is None:
#     251     einsum_names = [e.name for e in spec.workload.einsums]
# --> 253 pmapping_groups, pmapping_objects, einsum2jobs = pmapper.make_pmappings(
#     254     spec,
#     255     metrics=spec.mapper.metrics,
#     256     einsum_names=einsum_names,
#     257     can_combine_multiple_runs=can_combine_multiple_runs,
#     258     print_progress=print_progress,
#     259     one_pbar_only=one_pbar_only,
#     260 )
#     262 flattened_arches = {}
#     263 evaluated_specs = {}
#
# File /home/build/accelforge/mapper/FFM/_make_pmappings/make_pmappings.py:351, in make_pmappings(spec, can_combine_multiple_runs, metrics, einsum_names, fail_if_no_pmappings_for_einsum, print_progress, one_pbar_only)
#     345 spec = spec._spec_eval_expressions(
#     346     eval_arch=False,
#     347     eval_non_arch=True,
#     348 )
#     350 einsum2jobs = {}
# --> 351 new_einsum2jobs = get_jobs(
#     352     spec,
#     353     metrics,
#     354     einsum_names,
#     355     fail_if_no_pmappings_for_einsum,
#     356     print_progress,
#     357 )
#     358 _fill_jobs_with_memories_to_track(
#     359     new_einsum2jobs, spec, metrics, can_combine_multiple_runs, print_progress
#     360 )
#     361 for einsum_name, jobs in new_einsum2jobs.items():
#
# File /home/build/accelforge/mapper/FFM/_make_pmappings/make_pmappings.py:165, in get_jobs(spec, metrics, einsum_names, fail_if_no_pmappings_for_einsum, print_progress)
#     162 intermediate_tensors = input_tensors & output_tensors
#     164 n_einsums = len(spec.workload.einsum_names)
# --> 165 for einsum_name, jobs in parallel(
#     166     [
#     167         delayed(make_jobs_for_einsum)(
#     168             einsum_name,
#     169             spec._for_einsum(einsum_name),
#     170             stride_and_halo,
#     171             initial_delta_chocies[einsum_name],
#     172             n_einsums,
#     173             intermediate_tensors,
#     174         )
#     175         for einsum_name, spec in einsum2spec.items()
#     176     ],
#     177     pbar="Generating jobs" if print_progress else None,
#     178 ):
#     179     einsum2jobs.setdefault(einsum_name, {})
#     180     for compatibility, job_list in jobs.items():
#
# File /home/build/accelforge/util/parallel.py:188, in parallel(jobs, n_jobs, pbar, pbar_position, return_as)
#     186 results = [None] * total_jobs
#     187 args["return_as"] = "generator_unordered"
# --> 188 for i, result in yield_results():
#     189     results[i] = result
#     190 return results
#
# File /home/build/accelforge/util/parallel.py:170, in parallel.<locals>.yield_results()
#     169 def yield_results():
# --> 170     for result in Parallel(n_jobs=n_jobs, **args)(jobs):
#     171         if pbar:
#     172             pbar.update(1)
#
# File /usr/local/lib/python3.12/dist-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File /usr/local/lib/python3.12/dist-packages/joblib/parallel.py:1784, in Parallel._retrieve(self)
#    1778 while self._wait_retrieval():
#    1779     # If the callback thread of a worker has signaled that its task
#    1780     # triggered an exception, or if the retrieval loop has raised an
#    1781     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1782     # worker traceback.
#    1783     if self._aborting:
# -> 1784         self._raise_error_fast()
#    1785         break
#    1787     nb_jobs = len(self._jobs)
#
# File /usr/local/lib/python3.12/dist-packages/joblib/parallel.py:1859, in Parallel._raise_error_fast(self)
#    1855 # If this error job exists, immediately raise the error by
#    1856 # calling get_result. This job might not exists if abort has been
#    1857 # called directly or if the generator is gc'ed.
#    1858 if error_job is not None:
# -> 1859     error_job.get_result(self.timeout)
#
# File /usr/local/lib/python3.12/dist-packages/joblib/parallel.py:758, in BatchCompletionCallBack.get_result(self, timeout)
#     752 backend = self.parallel._backend
#     754 if backend.supports_retrieve_callback:
#     755     # We assume that the result has already been retrieved by the
#     756     # callback thread, and is stored internally. It's just waiting to
#     757     # be returned.
# --> 758     return self._return_or_raise()
#     760 # For other backends, the main thread needs to run the retrieval step.
#     761 try:
#
# File /usr/local/lib/python3.12/dist-packages/joblib/parallel.py:773, in BatchCompletionCallBack._return_or_raise(self)
#     771 try:
#     772     if self.status == TASK_ERROR:
# --> 773         raise self._result
#     774     return self._result
#     775 finally:
#
# KeyError: 'K'

# %%
print(result.latency(per_einsum=True))
print(result.energy(per_einsum=True))
print(result.actions(per_einsum=True, per_component=True))
# Out:
# {'T0': 0.34760600328445435, 'T1': 0.03903999924659729, 'T2': 0.03903999924659729, 'T3': 0.03903999924659729, 'T4': 0.03903999924659729, 'T5': 0.02740224078297615}
# {'T0': 0.017300856699657505, 'T1': 0.002913812526172331, 'T2': 0.00291381246796467, 'T3': 0.00291381246796467, 'T4': 0.00291381246796467, 'T5': 0.0018333830891938067}
# {('T0', 'FastInputScratchpad', 'read'): 7552892928.0, ('T0', 'FastInputScratchpad', 'write'): 472055808.0, ('T0', 'MainMemory', 'read'): 1145693696.0, ('T0', 'MainMemory', 'write'): 1078984704.0, ('T0', 'FastOutputScratchpad', 'read'): 14746124288.0, ('T0', 'FastOutputScratchpad', 'write'): 14746124288.0, ('T0', 'FastWeightScratchpad', 'read'): 7552892928.0, ('T0', 'FastWeightScratchpad', 'write'): 75264.0, ('T0', 'FastMAC', 'compute'): 944111616.0, ('T1', 'FastOutputScratchpad', 'read'): 7861174272.0, ('T1', 'FastOutputScratchpad', 'write'): 7861174272.0, ('T1', 'MainMemory', 'read'): 198475776.0, ('T1', 'MainMemory', 'write'): 51380224.0, ('T1', 'FastWeightScratchpad', 'read'): 7398752256.0, ('T1', 'FastWeightScratchpad', 'write'): 294912.0, ('T1', 'FastInputScratchpad', 'read'): 7398752256.0, ('T1', 'FastInputScratchpad', 'write'): 1277165568.0, ('T1', 'FastMAC', 'compute'): 924844032.0, ('T2', 'FastInputScratchpad', 'read'): 7398752256.0, ('T2', 'FastInputScratchpad', 'write'): 1277165568.0, ('T2', 'MainMemory', 'read'): 198475776.0, ('T2', 'MainMemory', 'write'): 51380224.0, ('T2', 'FastWeightScratchpad', 'read'): 7398752256.0, ('T2', 'FastWeightScratchpad', 'write'): 294912.0, ('T2', 'FastOutputScratchpad', 'read'): 7861174272.0, ('T2', 'FastOutputScratchpad', 'write'): 7861174272.0, ('T2', 'FastMAC', 'compute'): 924844032.0, ('T3', 'FastWeightScratchpad', 'read'): 7398752256.0, ('T3', 'FastWeightScratchpad', 'write'): 294912.0, ('T3', 'MainMemory', 'read'): 198475776.0, ('T3', 'MainMemory', 'write'): 51380224.0, ('T3', 'FastOutputScratchpad', 'read'): 7861174272.0, ('T3', 'FastOutputScratchpad', 'write'): 7861174272.0, ('T3', 'FastInputScratchpad', 'read'): 7398752256.0, ('T3', 'FastInputScratchpad', 'write'): 1277165568.0, ('T3', 'FastMAC', 'compute'): 924844032.0, ('T4', 'FastInputScratchpad', 'read'): 7398752256.0, ('T4', 'FastInputScratchpad', 'write'): 1277165568.0, ('T4', 'MainMemory', 'read'): 198475776.0, ('T4', 'MainMemory', 'write'): 51380224.0, ('T4', 'FastOutputScratchpad', 'read'): 7861174272.0, ('T4', 'FastOutputScratchpad', 'write'): 7861174272.0, ('T4', 'FastWeightScratchpad', 'read'): 7398752256.0, ('T4', 'FastWeightScratchpad', 'write'): 294912.0, ('T4', 'FastMAC', 'compute'): 924844032.0, ('T5', 'FastInputScratchpad', 'read'): 3699376128.0, ('T5', 'FastInputScratchpad', 'write'): 627572736.0, ('T5', 'MainMemory', 'read'): 123994112.0, ('T5', 'MainMemory', 'write'): 51380224.0, ('T5', 'FastOutputScratchpad', 'read'): 4238868480.0, ('T5', 'FastOutputScratchpad', 'write'): 4238868480.0, ('T5', 'FastWeightScratchpad', 'read'): 3699376128.0, ('T5', 'FastWeightScratchpad', 'write'): 589824.0, ('T5', 'FastMAC', 'compute'): 462422016.0}

# %%
actions = result.actions(per_einsum=True, per_component=True)
latency = result.latency(per_einsum=True)

total_reads = 0
total_writes = 0
for (einsum, lat) in latency.items():
    component = "MainMemory"
    reads = actions[(einsum, component, "read")]
    writes = actions[(einsum, component, "write")]
    print((reads + writes) / lat)
    total_reads += reads
    total_writes += writes
print(result.latency())
print((total_reads + total_writes) /result.latency())
# Out:
# 6399999939.527777
# 6400000123.508643
# 6400000123.508643
# 6400000123.508643
# 6400000123.508643
# 6399999817.130015
# 0.5311682
# 6.4e+09
